# %%
import pandas as pd 
from sklearn.datasets import load_diabetes
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error, root_mean_squared_error

# %%
d=load_diabetes()

df=pd.DataFrame(data=d.data,columns=d.feature_names)
df
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# 0    0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1   -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2    0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3   -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4    0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
# ..        ...       ...       ...       ...       ...       ...       ...
# 437  0.041708  0.050680  0.019662  0.059744 -0.005697 -0.002566 -0.028674
# 438 -0.005515  0.050680 -0.015906 -0.067642  0.049341  0.079165 -0.028674
# 439  0.041708  0.050680 -0.015906  0.017293 -0.037344 -0.013840 -0.024993
# 440 -0.045472 -0.044642  0.039062  0.001215  0.016318  0.015283 -0.028674
# 441 -0.045472 -0.044642 -0.073030 -0.081413  0.083740  0.027809  0.173816
#
#            s4        s5        s6
# 0   -0.002592  0.019907 -0.017646
# 1   -0.039493 -0.068332 -0.092204
# 2   -0.002592  0.002861 -0.025930
# 3    0.034309  0.022688 -0.009362
# 4   -0.002592 -0.031988 -0.046641
# ..        ...       ...       ...
# 437 -0.002592  0.031193  0.007207
# 438  0.034309 -0.018114  0.044485
# 439 -0.011080 -0.046883  0.015491
# 440  0.026560  0.044529 -0.025930
# 441 -0.039493 -0.004222  0.003064
#
# [442 rows x 10 columns]

# %%
sc=StandardScaler()
df=sc.fit_transform(df)

df=pd.DataFrame(data=df,columns=d.feature_names)

# %%
df['Target']=d.target

# %%
x=df.drop(columns='Target')

# %%
y=df['Target']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.8,random_state=42)

# %%
model=DecisionTreeRegressor()
model.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
prediction = model.predict(x_test)
prediction
# Out:
# array([206.,  99., 170., 150., 139.,  97., 233., 262., 200., 197.,  90.,
#        200.,  72., 220.,  86., 113., 317., 180., 293., 163., 147.,  65.,
#         49., 150., 103., 121., 281., 162.,  59., 183., 279.,  55., 172.,
#        292., 164., 180.,  94.,  74., 120.,  75.,  39.,  66., 199., 131.,
#        170.,  75.,  31., 170.,  45., 179., 142.,  75., 145., 179., 248.,
#        141.,  42., 221.,  42.,  57.,  67., 147., 142.,  91., 151., 163.,
#        126.,  69., 150., 179., 206., 283., 241., 162.,  75., 248., 220.,
#        178., 109., 248.,  49.,  25.,  59.,  45.,  65.,  52.,  74.,  74.,
#        147.])

# %%
print("Testing Effiency :",model.score(x_test,y_test))
print("Training Effiency:",model.score(x_train,y_train))
# Out:
# Testing Effiency : 0.06279379869639379
# Training Effiency: 1.0

# %%
mse=mean_squared_error(y_test,prediction)
mse
# Out:
# 4965.460674157303

# %%
r2_score(y_test,prediction)
# Out:
# 0.06279379869639379

# %%
root_mean_squared_error(y_test,prediction)
# Out:
# 70.46602496350495

# %%
mean_absolute_error(y_test,prediction)
# Out:
# 56.674157303370784
